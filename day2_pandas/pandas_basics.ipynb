# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10, 20, 30, 40])

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [21, 22, 23],
    "City": ["Delhi", "Mumbai", "Hyderabad"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age       City
# 0    Alice   21      Delhi
# 1      Bob   22     Mumbai
# 2  Charlie   23  Hyderabad

# %%
print(df.head())
# Out:
#       Name  Age       City
# 0    Alice   21      Delhi
# 1      Bob   22     Mumbai
# 2  Charlie   23  Hyderabad

# %%
print(df.head(1))
# Out:
#     Name  Age   City
# 0  Alice   21  Delhi

# %%
print(df.info())

print(df.shape)

print(df.columns)

print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None
# (3, 3)
# Index(['Name', 'Age', 'City'], dtype='object')
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
print(df.describe())
# Out:
#         Age
# count   3.0
# mean   22.0
# std     1.0
# min    21.0
# 25%    21.5
# 50%    22.0
# 75%    22.5
# max    23.0

# %%
print(df[1:2])
# Out:
#   Name  Age    City
# 1  Bob   22  Mumbai

# %%
print(df["Name"])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
print(df.loc[0])

print(df.loc[0:2])

print(df.iloc[0])

print(df.iloc[0:2])
# Out:
# Name    Alice
# Age        21
# City    Delhi
# Name: 0, dtype: object
#       Name  Age       City
# 0    Alice   21      Delhi
# 1      Bob   22     Mumbai
# 2  Charlie   23  Hyderabad
# Name    Alice
# Age        21
# City    Delhi
# Name: 0, dtype: object
#     Name  Age    City
# 0  Alice   21   Delhi
# 1    Bob   22  Mumbai

# %%
print(df.loc[0])

print(df.loc[0:2])

print(df.iloc[0])

print(df.iloc[0:2])
# Out:
# Name    Alice
# Age        21
# City    Delhi
# Name: 0, dtype: object
#       Name  Age       City
# 0    Alice   21      Delhi
# 1      Bob   22     Mumbai
# 2  Charlie   23  Hyderabad
# Name    Alice
# Age        21
# City    Delhi
# Name: 0, dtype: object
#     Name  Age    City
# 0  Alice   21   Delhi
# 1    Bob   22  Mumbai

# %%
df["Salary"] = [30000, 40000, 50000]

print(df)
# Out:
#       Name  Age       City  Salary
# 0    Alice   21      Delhi   30000
# 1      Bob   22     Mumbai   40000
# 2  Charlie   23  Hyderabad   50000

# %%
df["Age"] = df["Age"] + 1

# %%
df.isnull()

df.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    0
# dtype: int64

# %%
df.sort_values("Age")

df.sort_values("Age", ascending=False)
# Out:
#       Name  Age       City  Salary
# 2  Charlie   24  Hyderabad   50000
# 1      Bob   23     Mumbai   40000
# 0    Alice   22      Delhi   30000

# %%
df
# Out:
#       Name  Age       City  Salary
# 0    Alice   22      Delhi   30000
# 1      Bob   23     Mumbai   40000
# 2  Charlie   24  Hyderabad   50000

# %%
df["department"] = ["IT","IT","HR"]
df
# Out:
#       Name  Age       City  Salary department
# 0    Alice   22      Delhi   30000         IT
# 1      Bob   23     Mumbai   40000         IT
# 2  Charlie   24  Hyderabad   50000         HR

# %%
print(df.groupby("department")["Salary"].sum())
df
# Out:
# department
# HR    50000
# IT    70000
# Name: Salary, dtype: int64
#       Name  Age       City  Salary department
# 0    Alice   22      Delhi   30000         IT
# 1      Bob   23     Mumbai   40000         IT
# 2  Charlie   24  Hyderabad   50000         HR

# %%
df["Home Town"] = ["Guntur","Vijayawada",np.nan]
df
# Out:
#       Name  Age       City  Salary department   Home Town
# 0    Alice   22      Delhi   30000         IT      Guntur
# 1      Bob   23     Mumbai   40000         IT  Vijayawada
# 2  Charlie   24  Hyderabad   50000         HR         NaN

# %%
df.fillna("Ongole",inplace=True)
df
# Out:
#       Name  Age       City  Salary department   Home Town
# 0    Alice   22      Delhi   30000         IT      Guntur
# 1      Bob   23     Mumbai   40000         IT  Vijayawada
# 2  Charlie   24  Hyderabad   50000         HR      Ongole

# %%
students = pd.DataFrame({
    "ID" : [1,2,3],
    "Name" : ["Alice","Bob","Charlie"]
})

# %%
marks = pd.DataFrame({
    "ID": [1, 2, 4],
    "Marks": [85, 90, 75]
})

# %%
result = pd.merge(students, marks, on="ID", how="left")
print(result)
# Out:
#    ID     Name  Marks
# 0   1    Alice   85.0
# 1   2      Bob   90.0
# 2   3  Charlie    NaN

# %%
result = pd.merge(students, marks, on="ID", how="inner")
print(result)
# Out:
#    ID   Name  Marks
# 0   1  Alice     85
# 1   2    Bob     90

# %%
result = pd.merge(students, marks, on="ID", how="right")
print(result)
# Out:
#    ID   Name  Marks
# 0   1  Alice     85
# 1   2    Bob     90
# 2   4    NaN     75

# %%
df = pd.DataFrame({
    "Date": ["2026-08-01", "2026-08-02", "2026-08-05"]
})

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Year"] = df["Date"].dt.year

# %%
df["Day"] = df["Date"].dt.day

# %%
df["Weekday"] = df["Date"].dt.day_name()

# %%
df
# Out:
#         Date  Year  Day    Weekday
# 0 2026-08-01  2026    1   Saturday
# 1 2026-08-02  2026    2     Sunday
# 2 2026-08-05  2026    5  Wednesday
