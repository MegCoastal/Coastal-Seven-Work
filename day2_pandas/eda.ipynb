# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("ipl-matches.csv")

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
df.sample()
# Out:
#          ID    City        Date Season MatchNumber           Team1  \
# 480  829729  Mumbai  2015-04-17   2015          12  Mumbai Indians
#
#                    Team2             Venue      TossWinner TossDecision  \
# 480  Chennai Super Kings  Wankhede Stadium  Mumbai Indians          bat
#
#     SuperOver          WinningTeam    WonBy  Margin method Player_of_Match  \
# 480         N  Chennai Super Kings  Wickets     6.0    NaN         A Nehra
#
#                                           Team1Players  \
# 480  ['LMP Simmons', 'PA Patel', 'CJ Anderson', 'RG...
#
#                                           Team2Players       Umpire1  \
# 480  ['DR Smith', 'BB McCullum', 'SK Raina', 'F du ...  AK Chaudhary
#
#        Umpire2
# 480  M Erasmus

# %%
df[['TossWinner','WinningTeam']]
# Out:
#                       TossWinner                  WinningTeam
# 0               Rajasthan Royals               Gujarat Titans
# 1               Rajasthan Royals             Rajasthan Royals
# 2           Lucknow Super Giants  Royal Challengers Bangalore
# 3                 Gujarat Titans               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945              Deccan Chargers        Kolkata Knight Riders
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Rajasthan Royals             Delhi Daredevils
# 948          Chennai Super Kings          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
# [950 rows x 2 columns]

# %%
total_winning_runs = df.groupby("WinningTeam")["Margin"].sum()
total_winning_runs.sort_values(ascending=False)
# Out:
# WinningTeam
# Mumbai Indians                 2570.0
# Chennai Super Kings            2465.0
# Royal Challengers Bangalore    1999.0
# Kolkata Knight Riders          1875.0
# Rajasthan Royals               1468.0
# Kings XI Punjab                1323.0
# Sunrisers Hyderabad            1156.0
# Delhi Daredevils                950.0
# Delhi Capitals                  517.0
# Deccan Chargers                 493.0
# Punjab Kings                    212.0
# Lucknow Super Giants            181.0
# Pune Warriors                   175.0
# Gujarat Titans                  167.0
# Rising Pune Supergiant          154.0
# Rising Pune Supergiants          73.0
# Gujarat Lions                    66.0
# Kochi Tuskers Kerala             53.0
# Name: Margin, dtype: float64

# %%
df["Margin"].isnull().sum()
# Out:
# 18
