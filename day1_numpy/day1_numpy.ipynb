# %%
import numpy as np

# %%
# 1D array
a = np.array([1, 2, 3])

# 2D array
b = np.array([[1, 2, 3], [4, 5, 6]])

# Zeros, Ones
zeros = np.zeros((2, 3))
ones = np.ones((3, 3))

# Range
arr = np.arange(0, 10, 2)

# Evenly spaced numbers
lin = np.linspace(0, 1, 5)

# %%
print(a.shape)     # dimensions
print(a.size)     # number of elements
print(a.dtype)     # data type
# Out:
# (3,)
# 3
# int32

# %%
a = np.array([1, 2, 3])

a + 2
a * 3
np.sqrt(a)
np.mean(a)
np.sum(a)
np.max(a)
np.min(a)
# Out:
# 1

# %%
a = np.array([1, 2, 3, 4, 5])

a[0]        # first element
a[-1]       # last element
a[1:4]      # slicing
# Out:
# array([2, 3, 4])

# %%
b = np.array([[1, 2], [3, 4]])

b[0, 1]     # element at row 0, col 1
b[:, 1]     # all rows, second column
# Out:
# array([2, 4])

# %%
a = np.arange(6)

a.reshape(2, 3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.random.rand(3)          # random floats
np.random.randint(1, 10, 5) # random integers
# Out:
# array([1, 3, 8, 2, 1])

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])

np.dot(a, b)      # matrix multiplication
a.T               # transpose
np.linalg.inv(a)  # inverse
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
np.concatenate([a, b])
np.vstack([a, b])
np.hstack([a, b])
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %%
a = np.array([1, 2, 3, 4, 5])

# Create empty array
e = np.empty((2, 3))

# Identity matrix
i = np.eye(3)

# Diagonal matrix
d = np.diag([1, 2, 3])

# Full array
f = np.full((2, 2), 7)

# %%
print(e)
print(i)
print(d)
print(f)
# Out:
# [[1.06788918e-287 2.50521240e-292 3.00719473e-273]
#  [1.29196797e-263 5.55062520e-254 7.82850172e-249]]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[1 0 0]
#  [0 2 0]
#  [0 0 3]]
# [[7 7]
#  [7 7]]

# %%
arr = np.array([10, 20, 30, 40, 50])

print(np.mean(arr))
print(np.median(arr))
print(np.std(arr))
print(np.var(arr))
print(np.max(arr))
print(np.min(arr))
print(np.argmax(arr))
print(np.argmin(arr))
# Out:
# 30.0
# 30.0
# 14.142135623730951
# 200.0
# 50
# 10
# 4
# 0

# %%
arr = np.array([5, 2, 8, 1, 9])

print(np.sort(arr))
# Out:
# [1 2 5 8 9]

# %%
a = np.array([[3, 1], [4, 2]])

print(np.sort(a, axis=0))
print(np.sort(a, axis=1))
# Out:
# [[3 1]
#  [4 2]]
# [[1 3]
#  [2 4]]

# %%
arr = np.array([10, 15, 20, 25, 30])

print(arr[arr > 20])
print(arr[arr % 2 == 0])
# Out:
# [25 30]
# [10 20 30]

# %%
a = np.array([1, 2, 3])

print(a + 10)
print(a * 5)
# Out:
# [11 12 13]
# [ 5 10 15]

# %%
a = np.array([1, 2, 3])

print(a + 10)
print(a * 5)
# Out:
# [11 12 13]
# [ 5 10 15]
