# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
batsman = pd.read_csv("batter.csv")

# %%
batsman.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batsman = batsman.head(6)

# %%
plt.plot(batsman['batter'],batsman['avg'])
plt.grid()

# %%
plt.scatter(batsman['avg'],batsman['strike_rate'])

# %%
plt.bar(batsman['batter'],batsman['strike_rate'])
# Out:
# <BarContainer object of 6 artists>

# %%
data = [12,12,48,12,24]
subjects = ['english','hindi','telugu','maths','social']
plt.pie(data,labels=subjects)
# Out:
# ([<matplotlib.patches.Wedge at 0x17247482ad0>,
# ...
#  [Text(1.0336618818860421, 0.3762221603465248, 'english'),
#   Text(0.5499999925673781, 0.9526279484541089, 'hindi'),
#   Text(-1.0336618906921569, 0.3762221361519225, 'telugu'),
#   Text(-0.19101295880800456, -1.083288534771513, 'maths'),
#   Text(0.8426489168532442, -0.7070663355909788, 'social')])

# %%
batsman = ['AB de Villiers','CH Gayle','SS Tiwary','TM Dilshan','V Kohli']
runs = [31,175,2,33,11]
plt.pie(runs,labels=batsman)
# Out:
# ([<matplotlib.patches.Wedge at 0x17247550590>,
# ...
#  [Text(1.0188716521172982, 0.4146089199616521, 'AB de Villiers'),
#   Text(-1.080823103689079, 0.20450285702626878, 'CH Gayle'),
#   Text(0.4772719502320876, -0.991065833091657, 'SS Tiwary'),
#   Text(0.8513978212106521, -0.6965068198070674, 'TM Dilshan'),
#   Text(1.0896731766047492, -0.1503740941389678, 'V Kohli')])

# %%
plt.pie(runs,labels=batsman,explode=[0.0,0,0,0,0.5])
# Out:
# ([<matplotlib.patches.Wedge at 0x172476d4750>,
# ...
#  [Text(1.0188716521172982, 0.4146089199616521, 'AB de Villiers'),
#   Text(-1.080823103689079, 0.20450285702626878, 'CH Gayle'),
#   Text(0.4772719502320876, -0.991065833091657, 'SS Tiwary'),
#   Text(0.8513978212106521, -0.6965068198070674, 'TM Dilshan'),
#   Text(1.5849791659705441, -0.2187259551112259, 'V Kohli')])
